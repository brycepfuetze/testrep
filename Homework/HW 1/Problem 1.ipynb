# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# **Problem 1**

# %%
# Set values for x
x = np.arange(1.920,2.080,0.001)
print(x)
# Out:
# [1.92  1.921 1.922 1.923 1.924 1.925 1.926 1.927 1.928 1.929 1.93  1.931
#  1.932 1.933 1.934 1.935 1.936 1.937 1.938 1.939 1.94  1.941 1.942 1.943
#  1.944 1.945 1.946 1.947 1.948 1.949 1.95  1.951 1.952 1.953 1.954 1.955
#  1.956 1.957 1.958 1.959 1.96  1.961 1.962 1.963 1.964 1.965 1.966 1.967
#  1.968 1.969 1.97  1.971 1.972 1.973 1.974 1.975 1.976 1.977 1.978 1.979
#  1.98  1.981 1.982 1.983 1.984 1.985 1.986 1.987 1.988 1.989 1.99  1.991
#  1.992 1.993 1.994 1.995 1.996 1.997 1.998 1.999 2.    2.001 2.002 2.003
#  2.004 2.005 2.006 2.007 2.008 2.009 2.01  2.011 2.012 2.013 2.014 2.015
#  2.016 2.017 2.018 2.019 2.02  2.021 2.022 2.023 2.024 2.025 2.026 2.027
#  2.028 2.029 2.03  2.031 2.032 2.033 2.034 2.035 2.036 2.037 2.038 2.039
#  2.04  2.041 2.042 2.043 2.044 2.045 2.046 2.047 2.048 2.049 2.05  2.051
#  2.052 2.053 2.054 2.055 2.056 2.057 2.058 2.059 2.06  2.061 2.062 2.063
#  2.064 2.065 2.066 2.067 2.068 2.069 2.07  2.071 2.072 2.073 2.074 2.075
# ...

# %%
# calculate y using the expanded version of (x-2)^2
y_full = x**9 - 18*x**8 + 144*x**7 - 672*x**6 + 2016*x**5 - 4032*x**4 + 5376*x**3 - 4608*x**2 + 2304*x - 512
fig = px.line(x = x, y = y_full)

# Plot!
fig.update_layout(
    title="Expanded Polynomial",
    xaxis_title="x",
    yaxis_title="p(x)",
    yaxis = dict(
        showexponent = 'all',
        exponentformat = 'e'
    ))
fig.show()

# %%
# calculate y using the factored version
y_condensed = (x-2)**9

# Plot!
fig = px.line(x = x, y = y_condensed)
fig.update_layout(
    title="Factored Polynomial",
    xaxis_title="x",
    yaxis_title="p(x)",
        yaxis = dict(
        showexponent = 'all',
        exponentformat = 'e')
)
fig.show()

# %% [markdown]
# **Problem 5**

# %%
delta = np.logspace(-16,0,17)
print(delta)
# Out:
# [1.e-16 1.e-15 1.e-14 1.e-13 1.e-12 1.e-11 1.e-10 1.e-09 1.e-08 1.e-07
#  1.e-06 1.e-05 1.e-04 1.e-03 1.e-02 1.e-01 1.e+00]

# %%
x1 = np.pi
x2 = 10**6
original1 = np.cos(x1 - delta) - np.cos(x1)
original2 = np.cos(x2 - delta) - np.cos(x2)

manipulated1 = 2 * np.sin((2*x1 + delta)/2) * np.sin(-delta/2)
manipulated2 = 2 * np.sin((2*x2 + delta)/2) * np.sin(-delta/2)

# %%
fig = px.line(x = delta, y = original1, log_x=True)
fig.update_layout(
    title="Original, x = pi",
    xaxis_title="delta",
    yaxis_title="y",
        yaxis = dict(
        showexponent = 'all',
        exponentformat = 'e')
)
fig.show()

# %%
fig = px.line(x = delta, y = original2, log_x=True)
fig.update_layout(
    title="Original, x = 10^6",
    xaxis_title="delta",
    yaxis_title="y",
        yaxis = dict(
        showexponent = 'all',
        exponentformat = 'e')
)
fig.show()

# %%
fig = px.line(x = delta, y = manipulated1, log_x=True)
fig.update_layout(
    title="Manipulated, x = pi",
    xaxis_title="delta",
    yaxis_title="y",
        yaxis = dict(
        showexponent = 'all',
        exponentformat = 'e')
)
fig.show()

# %%
fig = px.line(x = delta, y = manipulated2, log_x=True)
fig.update_layout(
    title="Manipulated, x = 10^6",
    xaxis_title="delta",
    yaxis_title="y",
        yaxis = dict(
        showexponent = 'all',
        exponentformat = 'e')
)
fig.show()

# %%
taylor1 = -delta * np.sin(x1)
taylor2 = -delta * np.sin(x2)

# %%
fig = px.line(x = delta, y = taylor1, log_x=True)
fig.update_layout(
    title="Taylor, x = pi",
    xaxis_title="delta",
    yaxis_title="y",
        yaxis = dict(
        showexponent = 'all',
        exponentformat = 'e')
)
fig.show()

# %%
fig = px.line(x = delta, y = taylor2, log_x=True)
fig.update_layout(
    title="Taylor, x = 10^6",
    xaxis_title="delta",
    yaxis_title="y",
        yaxis = dict(
        showexponent = 'all',
        exponentformat = 'e')
)
fig.show()
